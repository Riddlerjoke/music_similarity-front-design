# %%
import os
import pickle
import random

from pathlib import Path
from utils.music_utils import *

import numpy as np

# %%
DATASET = Path("MegaSet")

mp3_files = list(DATASET.glob("**/*.mp3"))
print("Found {} mp3 files".format(len(mp3_files)))
# Out:
# Found 11637 mp3 files

# %%
valid_mp3_files = []
invalid_mp3_files = []
total_mp3_files = len(mp3_files)

for mp3_file in mp3_files:
    if not check_predictions_87(mp3_file) or not check_embeddings_512(mp3_file):
        invalid_mp3_files.append(mp3_file)
    else:
        valid_mp3_files.append(mp3_file)

# calculate the percentage of valid mp3 files
percentage_valid = len(valid_mp3_files) / total_mp3_files * 100
print(f"found {len(valid_mp3_files)} valid pkl files out of {total_mp3_files}, percentage valid: {percentage_valid:.2f}%")
# Out:
# found 11637 valid pkl files out of 11637, percentage valid: 100.00%

# %%
pkl_files = list(DATASET.glob("**/*.pkl"))
long_fields = []
for path in pkl_files:
    with path.open("rb") as f:
        file_info = pickle.load(f)
        title = file_info.get("title")
        artist = file_info.get("artist")
        if (
            (not title or len(title) > 160)
            or (not artist or len(artist) > 160)
        ):
            long_fields.append(path)

# Print the paths of the files with a title or artist field of length > 120
for path in long_fields:
    print(path)

# %%
#######################################################################################""

# %%
# for each mp3 file in Path(), pass the path of mp3 file to file 
# and path to openl3-music-mel128-emb512-3.pb to the function get_top_5_genres
# data["top_5_genres"] = get_top_5_genres(file, path)
# then add the new field to the pkl file and save it

pkl_files = list(DATASET.glob("**/*.pkl"))

for path in pkl_files:
    with path.open("rb") as f:
        file_info = pickle.load(f)
        top5_list = get_top_5_genres(file_info["filepath"], "utils/mtg_jamendo_genre.json")
        file_info['top_5_genres'] = top5_list
        with path.open("wb") as f:
            pickle.dump(file_info, f)

# %%
print_info(pick_random_mp3(DATASET))
# Out:
# filename: 09 - Omegaman.mp3
# filepath: MegaSet/The Police/The Police - 1981 - Ghost In The Machine/09 - Omegaman.mp3
# folder: MegaSet/The Police/The Police - 1981 - Ghost In The Machine
# filesize: 6.43
# title: Omegaman
# artist: The Police
# album: Ghost in the Machine
# year: 1981
# tracknumber: 9
# genre: Rock
# predictions_87: [3.36013804e-03 4.73670755e-03 2.46243477e-02 1.05551453e-02
#  2.01205350e-03 1.82846129e-01 1.98388770e-02 1.41158020e-02
#  2.58189579e-03 9.65908077e-03 4.77614207e-03 7.18725438e-04
#  1.78280647e-03 2.56507075e-03 1.88134273e-03 5.86511288e-03
#  1.21534592e-03 9.99966450e-03 4.67064744e-03 1.17154093e-03
#  9.44283849e-04 4.61289100e-03 9.60312039e-03 8.01805058e-04
#  2.55202758e-03 5.17116045e-04 5.16835088e-03 1.66761375e-03
#  1.89767953e-03 1.24031631e-03 1.83640397e-03 1.24356197e-02
#  5.34250459e-04 8.69936794e-02 1.67727878e-03 7.99973123e-03
#  1.28559675e-03 7.10277876e-04 3.05239353e-02 1.06712254e-02
#  4.38345149e-02 6.77412096e-03 6.82105916e-03 1.26946839e-02
#  2.03191247e-02 1.02484524e-01 4.40107193e-03 2.99881864e-03
#  4.27471328e-04 2.43147532e-03 2.63297409e-01 5.26579795e-03
#  1.86541267e-02 8.84649903e-02 6.41865190e-03 7.73968000e-04
#  1.68124016e-03 4.52045212e-03 6.27834466e-04 6.43647760e-02
#  1.26339705e-03 2.45345454e-03 1.76077876e-02 5.30174049e-03
