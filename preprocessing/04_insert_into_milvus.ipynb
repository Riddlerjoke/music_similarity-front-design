# %%
import pickle
import random
from pathlib import Path
import json
import music_tag
import numpy as np
import os
from utils.music_utils import *

from pymilvus import connections, utility
from pymilvus import Collection, DataType, FieldSchema, CollectionSchema

# %%
DATASET = Path('MegaSet')
# count the mp3 and pkl files in DATASET

count_mp3 = 0   
count_pkl = 0
for root, dirs, files in os.walk(DATASET):
    for file in files:
        if file.endswith('.mp3'):
            count_mp3 += 1
        if file.endswith('.pkl'):
            count_pkl += 1
print(f"founds {count_mp3} mp3 files and {count_pkl} pkl files")
# Out:
# founds 11637 mp3 files and 11637 pkl files

# %%
pkl_files = list(DATASET.glob('**/*.pkl'))

types87 = []
types512 = []

for pkl_path in pkl_files:
    with pkl_path.open('rb') as f:
        try:
            content = pickle.load(f)
            embed = content.get('embedding_512')
            if embed is not None:
                types87.append(type(embed))
                types512.append(type(embed))
        except Exception as e:
            print(f"Error reading file {pkl_path}: {e}")

unique_types87 = set(types87)
unique_types512 = set(types512)

print(f"Unique types 87: {unique_types87}")
print(f"Unique types 512: {unique_types512}")
# Out:
# Unique types 87: {<class 'numpy.ndarray'>}
# Unique types 512: {<class 'numpy.ndarray'>}

# %%
print_info(pick_random_mp3(DATASET))
# Out:
# filename: 12. Katie Melua - The House.mp3
# filepath: MegaSet/Katie Melua/Katie Melua - 2010 - The House/12. Katie Melua - The House.mp3
# folder: MegaSet/Katie Melua/Katie Melua - 2010 - The House
# filesize: 5.88
# title: The House
# artist: Katie Melua
# album: The House
# year: 2010
# tracknumber: 12
# genre: Pop
# predictions_87: [0.00402669 0.00223018 0.00242836 0.00310962 0.00212826 0.10296998
#  0.00331248 0.15418217 0.03190089 0.02666511 0.00111806 0.00174515
#  0.00142048 0.01870859 0.01331209 0.04728153 0.00393937 0.06470482
#  0.00551657 0.00110773 0.00949835 0.01578013 0.00371254 0.00745916
#  0.00482683 0.00067051 0.00139667 0.0121285  0.00109338 0.001048
#  0.00138212 0.1109677  0.00097812 0.15695696 0.00206799 0.00722451
#  0.01399639 0.00052159 0.0486715  0.14298022 0.00241574 0.00482373
#  0.00082823 0.00294661 0.00091043 0.00219242 0.00794023 0.00247123
#  0.00134016 0.00403215 0.0821307  0.00581988 0.03051211 0.01617099
#  0.01726036 0.00155757 0.006372   0.04027506 0.00412078 0.01179634
#  0.00461762 0.08306865 0.00294535 0.04668625 0.29880926 0.09339348
#  0.03670445 0.01204601 0.01332123 0.01858372 0.00150711 0.00367644
#  0.00209926 0.00254453 0.12680236 0.00203335 0.04104643 0.00458957
#  0.18711309 0.0018215  0.01261198 0.00425157 0.00352165 0.0030976
#  0.0141083  0.06478351 0.0026851 ]
# embedding_512: [ 3.255233    0.40509313  1.7214332   2.7376273   1.2815435   1.7743068
#   1.1213475   1.8220316   3.1600797   2.1554255   2.1504066   4.0154486
#   2.5241334   1.7813779   2.7799141   4.8183045   1.4624557   1.9805704
#   2.81249     1.9592643   2.661505    1.942627    1.3219172   3.2793891
#   2.314459    2.2482958   1.5745476   2.2327719   1.2279507   1.9732021
#   2.0602145   2.347491    1.7944885   2.494012    1.4370396   2.8311858
#   0.90029544  2.0087473   2.0667708   2.520758    3.0010478   3.332382
#   3.1848044   2.0673332   1.0039071   3.9548364   3.8019898   1.4421998
#   1.7207959   2.5631742   1.736216    1.6158576   2.3067906  -0.6475549
#   2.135296    1.6473595   2.3567743   2.3049743   3.292618    1.5818218
#   1.7894034   3.6778908   1.9504663   2.1971707   1.8164513   3.166861
#   1.8370159   2.3387697   2.0143552   2.792061    2.9496028   1.637751
#   1.6108068   1.8517134   3.1032925   2.0237594   1.8117114   1.929094
#   2.2414145   1.7088393   2.0426745   1.8901141   1.8538598   1.6127529
#   1.7218846   3.007929    3.4766014   4.1268697   1.73287     3.4899473
#   3.1281822   3.2008107   1.5797148   3.334261    3.1405106   1.9411877
#   3.2883916   1.7191485   2.2657158   3.9294147   3.8442335   1.8714852
#   1.480461    1.8881708   3.1107416   2.2386994   2.0234377   4.115497
#   2.8751519   1.2685447   1.3484423   1.6378071   3.4093807   1.3667194
#   3.0927236   2.2248702   0.9328654   0.83122504  1.2699215   1.8361442
#   2.1296535   2.3465734   2.4107919   1.5339892   3.1617327   2.296429
#   1.8686116   1.046952    4.1394296   2.613435    1.8108909   1.2717595
#   2.0848732   2.6143029   1.8812764   1.2133293   3.2962961   2.3283231
#   2.6905258   2.8874876   2.6926289   1.5497086   2.5689585   2.5785556
#   3.0770059   2.9953978   1.8798947   1.3543025   4.0339794   1.7241781
#   2.352428    3.43527     1.3568299   2.1437547   2.0043046   1.0816946
#   1.5190192   3.4832246   1.6549718   2.808678    2.7428472   0.9433781
#   1.4609756   2.1721928   2.5269318   1.7873652   0.9391545   2.6936772
#   3.0389464   1.6044952   1.8037944   1.9739136   2.4881277   1.5554041
#   2.6221108   3.1644378   2.6830602   1.1994877   1.9765273   1.8833264
#   2.1126864   2.2332366   4.2616057   1.89382     1.1410015   2.7504995
#   2.6945906   3.4331791   2.2317228   2.3144257   3.1222088   2.6692061
#   1.8347505   1.2554345   2.7203448   2.1505218   2.007942    2.0712337
#   2.238539    2.1376724   1.8579805   4.036154    1.4525564   1.99788
#   2.2181509   3.4127035   2.9771798   3.462794    2.6466892   2.3006687
#   1.4265466   2.094653    1.5987843   1.9079869   3.8151612   3.3247597
#   1.9792475   2.5918944   2.4575155   2.607823    1.1832055   1.3835216
#   0.8555885   1.9481145   2.6327531   1.7257998   1.1217796   2.7399082
#   3.5366938   1.8931533   3.7016678   1.818339    3.0284464   1.6913428
#   1.4164536   1.1267833   1.9086633   2.831105    2.011596    3.702507
#   3.501652    3.3536344   3.4932768   2.0349178   1.0993637   2.0517733
#   2.3775232   1.7897755   3.2540073   1.9753022   2.5785098   1.7992351
#   1.9740928   3.5506127   1.9529779   2.481464    1.5799131   2.2708251
#   2.5408344   1.9411868   0.949587    2.0418925   2.0424807   3.6993153
#   2.752769    1.2759362   3.7675693   4.045513    1.2901167   1.9429944
#   4.960703    2.596094    4.665025    3.2429774   2.1735778   2.8103125
#   2.093433    2.4612014   3.7140636   1.9392409   1.5863999   1.6373773
#   3.0713353   3.2686098   2.4387147   2.7986205   1.3089861   2.3000727
#   1.7284529   1.7362165   1.4003705   0.7777399   3.1322873   1.3544811
#   2.4326975   2.3151777   2.2064123   4.662668    1.8031837   2.157818
#   1.6024307   2.153791    1.3210102   2.5549364   3.4609265   2.573711
#   2.3575332   3.1989846   2.071985    1.9140668   3.8224878   1.5552113
#   1.6034317   1.9964743   2.3443716   2.3164456   2.5886579   2.4732168
#   3.0596628   2.6178253   3.2503943   1.9103397   3.0286453   2.5877228
#   1.7172381   0.8616912   1.3407706   1.6739628   3.1480467   3.2323341
#   2.7776833   2.2540138   1.6286167   2.6278162   2.822224    2.189825
#   2.36517     2.211321    1.5764449   4.0962853   2.626932    1.5724876
#   2.505043    2.7681174   1.5654459   2.5932477   1.8725196   2.7494597
#   3.0806837   2.4273894   4.0818934   1.7225202   4.062456    1.443615
#   3.4943597   1.4746501   2.140106    2.8959875   1.9451284   1.6652038
#   1.4035501   1.1844994   2.3798919   2.9464715   3.277305    2.911162
#   1.8497396   2.1605017   1.1389017   1.5096354   1.6739763   1.4935668
#   2.3095381   2.7149746   3.3694394   3.3325887   2.0880108   1.4150056
#   1.8578833   0.85629696  2.2890155   3.3282185   3.429845    1.5689541
#   2.4152424   1.4606065   3.1548767   1.8982912   2.7943614   2.0699606
#   3.5230927   2.3961656   2.4904106   2.862588    3.7276542   2.4280972
#   1.7272955   2.627018    1.8069417   1.4725238   1.4105053   2.3953826
#   3.1891768   2.3732424   3.211082    2.3637397   1.0367624   3.1579359
#   2.7397397   3.7741902   2.5843194   1.062779    2.5772974   2.077804
#   2.0011492   1.9242176   0.99546784  1.261215    0.7936053   2.2367048
#   3.360932    1.3826318   2.5452065   1.2926393   2.1570156   1.7520441
#   2.0067387   2.114914    1.5958793   1.7754924   2.2209885   2.6388805
#   2.6896615   2.0585825   2.6303225   2.9322336   1.8484972   1.2428619
#   1.5284241   3.1889067   2.540114    3.785885    2.2846012   2.71491
#   2.8252587   1.105272    1.2398918   2.610097    3.6810932   1.4439974
#   1.8901262   2.5129454   1.5244781   3.37538     2.211101    2.8575816
#   1.1622939   2.6431193   0.68877393  2.6899474   3.6381946   2.3947308
#   1.7649803   1.4857934   3.3363588   1.9496417   2.8292708   2.106832
#   0.85063463  2.2341626   2.4785912   3.390343    3.3865175   2.0661073
#   2.1035585   0.9855595   1.2605317   3.5452886   2.2781668   2.0588374
#   1.2958428   2.6192346   1.1727669   2.815702    3.5850725   2.4983368
#   2.8269541   2.107218    2.1698375   3.6790848   2.5681558   2.6094668
#   1.3317137   1.732586    2.1706843   2.5846226   3.8033786   2.3809102
#   2.847947    1.8163717   2.1141908   3.9865496   2.9453874   2.6200683
#   2.9085798   2.0194046   2.1274474   3.076699    2.3898246   2.241335
#   1.5643301   3.6437151 ]
# top_5_genres: ['pop', 'soundtrack', 'electronic', 'ambient', 'folk']

# %%
########## Milvus Client ##########

# %%
from dotenv import load_dotenv
import os
load_dotenv()

URI = os.getenv("MILVUS_URI")
TOKEN = os.getenv("MILVUS_TOKEN")

# %%
# connect to milvus
connections.connect("default",
                    uri=URI,
                    token=TOKEN)
print(f"Connecting to DB: {URI}")
# Out:
# Connecting to DB: https://in03-efa63c0579a14a1.api.gcp-us-west1.zillizcloud.com

# %%
########## predictions_87 ##########

# %%
print(utility.list_collections())
# Out:
# ['embeddings_512', 'predictions_87']

# %%
# Check if the collection exists
check_collection_name = 'predictions_87'

check_collection = utility.has_collection(check_collection_name )
if check_collection:
    drop_result = utility.drop_collection(check_collection_name )

print(utility.list_collections())
# Out:
# ['embeddings_512']

# %%
# create a collection for prediction_87
collection_name = "predictions_87"
dimension = 87

# Define the schema
schema = CollectionSchema(
    fields=[
        FieldSchema(name="id",dtype=DataType.INT64,is_primary=True,auto_id=False,max_length=100),
        FieldSchema(name="path", dtype=DataType.VARCHAR, max_length=280),
        FieldSchema(name="title", dtype=DataType.VARCHAR, max_length=220),
        FieldSchema(name="artist", dtype=DataType.VARCHAR, max_length=120),
        FieldSchema(name="album", dtype=DataType.VARCHAR, max_length=240),
        FieldSchema(name="predictions", dtype=DataType.FLOAT_VECTOR, dim=dimension),
        FieldSchema(name="top_5_genres", dtype=DataType.ARRAY, element_type=DataType.VARCHAR, max_capacity=5, max_length=100),
        ],
    enable_dynamic_field=True,  # Optional, defaults to 'False'.
)

print(f"Creating example collection: {collection_name}")
collection = Collection(collection_name, schema)
print(f"Schema: {schema}")
print("Success!")
# Out:
# Creating example collection: predictions_87
# Schema: {'auto_id': False, 'description': '', 'fields': [{'name': 'id', 'description': '', 'type': <DataType.INT64: 5>, 'is_primary': True, 'auto_id': False}, {'name': 'path', 'description': '', 'type': <DataType.VARCHAR: 21>, 'params': {'max_length': 280}}, {'name': 'title', 'description': '', 'type': <DataType.VARCHAR: 21>, 'params': {'max_length': 220}}, {'name': 'artist', 'description': '', 'type': <DataType.VARCHAR: 21>, 'params': {'max_length': 120}}, {'name': 'album', 'description': '', 'type': <DataType.VARCHAR: 21>, 'params': {'max_length': 240}}, {'name': 'predictions', 'description': '', 'type': <DataType.FLOAT_VECTOR: 101>, 'params': {'dim': 87}}, {'name': 'top_5_genres', 'description': '', 'type': <DataType.ARRAY: 22>, 'params': {'max_length': 100, 'max_capacity': 5}, 'element_type': <DataType.VARCHAR: 21>}], 'enable_dynamic_field': True}
# Success!

# %%
import logging
from multiprocessing import Pool

# Set up logging
logging.basicConfig(filename='app.log', filemode='w', format='%(name)s - %(levelname)s - %(message)s')


def process_file(args):
    i, path = args
    try:
        with open(path, "rb") as f:
            data = pickle.load(f)
            filepath = data.get("filepath")
            title = data.get("title")
            album = data.get("album")
            artist = data.get("artist")
            predictions = data.get("predictions_87")
            top_5_genres = data.get("top_5_genres")

        if isinstance(predictions, np.ndarray):
            return (i, filepath, title, album, artist, predictions, top_5_genres)
    except Exception as e:
        logging.error(f"Error processing file {path}: {str(e)}")
        return None

# %%
# Use a multiprocessing pool to process the files in parallel
with Pool() as p:
    results = p.map(process_file, enumerate(pkl_files))

# Filter out None results
results = [r for r in results if r is not None]

# Batch size
batch_size = 18

fails = []

# Insert the data into the collection
for i in range(0, len(results), batch_size):
    id_batch, path_batch, title_batch, album_batch, artist_batch, predictions_batch, top_5_genres_batch = zip(*results[i : i + batch_size])
    documents = [
        {
            "id": id,
            "path": path,
            "title": title,
            "album": album,
            "artist": artist,
            "predictions": predictions.tolist(),
            "top_5_genres": top_5_genres
        }
        for id, path, title, album, artist, predictions, top_5_genres in zip(
            id_batch, path_batch, title_batch, album_batch, artist_batch, predictions_batch, top_5_genres_batch,
        )
    ]
    try:
        collection.insert(documents)
        print(f"Inserted {i + batch_size} records into collection {collection.name}.")
    except Exception as e:
        fails.append((i + batch_size, documents))
        print(f"Error inserting batch {i + batch_size} into collection {collection.name}. Error: {str(e)}")

# 2m 11.0s
# Out:
# Inserted 18 records into collection predictions_87.
# Inserted 36 records into collection predictions_87.
# Inserted 54 records into collection predictions_87.
# Inserted 72 records into collection predictions_87.
# Inserted 90 records into collection predictions_87.
# Inserted 108 records into collection predictions_87.
# Inserted 126 records into collection predictions_87.
# Inserted 144 records into collection predictions_87.
# Inserted 162 records into collection predictions_87.
# Inserted 180 records into collection predictions_87.
# Inserted 198 records into collection predictions_87.
# Inserted 216 records into collection predictions_87.
# Inserted 234 records into collection predictions_87.
# Inserted 252 records into collection predictions_87.
# Inserted 270 records into collection predictions_87.
# Inserted 288 records into collection predictions_87.
# Inserted 306 records into collection predictions_87.
# Inserted 324 records into collection predictions_87.
# Inserted 342 records into collection predictions_87.
# Inserted 360 records into collection predictions_87.
# Inserted 378 records into collection predictions_87.
# Inserted 396 records into collection predictions_87.
# Inserted 414 records into collection predictions_87.
# Inserted 432 records into collection predictions_87.
# Inserted 450 records into collection predictions_87.
# Inserted 468 records into collection predictions_87.
# Inserted 486 records into collection predictions_87.
# Inserted 504 records into collection predictions_87.
# Inserted 522 records into collection predictions_87.
# Inserted 540 records into collection predictions_87.
# Inserted 558 records into collection predictions_87.
# Inserted 576 records into collection predictions_87.
# Inserted 594 records into collection predictions_87.
# Inserted 612 records into collection predictions_87.
# Inserted 630 records into collection predictions_87.
# Inserted 648 records into collection predictions_87.
# Inserted 666 records into collection predictions_87.
# Inserted 684 records into collection predictions_87.
# Inserted 702 records into collection predictions_87.
# Inserted 720 records into collection predictions_87.
# Inserted 738 records into collection predictions_87.
# Inserted 756 records into collection predictions_87.
# Inserted 774 records into collection predictions_87.
# Inserted 792 records into collection predictions_87.
# Inserted 810 records into collection predictions_87.
# Inserted 828 records into collection predictions_87.
# Inserted 846 records into collection predictions_87.
# Inserted 864 records into collection predictions_87.
# Inserted 882 records into collection predictions_87.
# Inserted 900 records into collection predictions_87.
# Inserted 918 records into collection predictions_87.
# Inserted 936 records into collection predictions_87.
# Inserted 954 records into collection predictions_87.
# Inserted 972 records into collection predictions_87.
# Inserted 990 records into collection predictions_87.
# Inserted 1008 records into collection predictions_87.
# Inserted 1026 records into collection predictions_87.
# Inserted 1044 records into collection predictions_87.
# Inserted 1062 records into collection predictions_87.
# Inserted 1080 records into collection predictions_87.
# Inserted 1098 records into collection predictions_87.
# Inserted 1116 records into collection predictions_87.
# Inserted 1134 records into collection predictions_87.
# Inserted 1152 records into collection predictions_87.
# Inserted 1170 records into collection predictions_87.
# Inserted 1188 records into collection predictions_87.
# Inserted 1206 records into collection predictions_87.
# Inserted 1224 records into collection predictions_87.
# Inserted 1242 records into collection predictions_87.
# Inserted 1260 records into collection predictions_87.
# Inserted 1278 records into collection predictions_87.
# Inserted 1296 records into collection predictions_87.
# Inserted 1314 records into collection predictions_87.
# Inserted 1332 records into collection predictions_87.
# Inserted 1350 records into collection predictions_87.
# Inserted 1368 records into collection predictions_87.
# Inserted 1386 records into collection predictions_87.
# Inserted 1404 records into collection predictions_87.
# Inserted 1422 records into collection predictions_87.
# Inserted 1440 records into collection predictions_87.
# Inserted 1458 records into collection predictions_87.
# Inserted 1476 records into collection predictions_87.
# Inserted 1494 records into collection predictions_87.
# Inserted 1512 records into collection predictions_87.
# Inserted 1530 records into collection predictions_87.
# Inserted 1548 records into collection predictions_87.
# Inserted 1566 records into collection predictions_87.
# Inserted 1584 records into collection predictions_87.
# Inserted 1602 records into collection predictions_87.
# Inserted 1620 records into collection predictions_87.
# Inserted 1638 records into collection predictions_87.
# Inserted 1656 records into collection predictions_87.
# Inserted 1674 records into collection predictions_87.
# Inserted 1692 records into collection predictions_87.
# Inserted 1710 records into collection predictions_87.
# Inserted 1728 records into collection predictions_87.
# Inserted 1746 records into collection predictions_87.
# Inserted 1764 records into collection predictions_87.
# Inserted 1782 records into collection predictions_87.
# Inserted 1800 records into collection predictions_87.
# Inserted 1818 records into collection predictions_87.
# Inserted 1836 records into collection predictions_87.
# Inserted 1854 records into collection predictions_87.
# Inserted 1872 records into collection predictions_87.
# Inserted 1890 records into collection predictions_87.
# Inserted 1908 records into collection predictions_87.
# Inserted 1926 records into collection predictions_87.
# Inserted 1944 records into collection predictions_87.
# Inserted 1962 records into collection predictions_87.
# Inserted 1980 records into collection predictions_87.
# Inserted 1998 records into collection predictions_87.
# Inserted 2016 records into collection predictions_87.
# Inserted 2034 records into collection predictions_87.
# Inserted 2052 records into collection predictions_87.
# Inserted 2070 records into collection predictions_87.
# Inserted 2088 records into collection predictions_87.
# Inserted 2106 records into collection predictions_87.
# Inserted 2124 records into collection predictions_87.
# Inserted 2142 records into collection predictions_87.
# Inserted 2160 records into collection predictions_87.
# Inserted 2178 records into collection predictions_87.
# Inserted 2196 records into collection predictions_87.
# Inserted 2214 records into collection predictions_87.
# Inserted 2232 records into collection predictions_87.
# Inserted 2250 records into collection predictions_87.
# Inserted 2268 records into collection predictions_87.
# Inserted 2286 records into collection predictions_87.
# Inserted 2304 records into collection predictions_87.
# Inserted 2322 records into collection predictions_87.
# Inserted 2340 records into collection predictions_87.
# Inserted 2358 records into collection predictions_87.
# Inserted 2376 records into collection predictions_87.
# Inserted 2394 records into collection predictions_87.
# Inserted 2412 records into collection predictions_87.
# Inserted 2430 records into collection predictions_87.
# Inserted 2448 records into collection predictions_87.
# Inserted 2466 records into collection predictions_87.
# Inserted 2484 records into collection predictions_87.
# Inserted 2502 records into collection predictions_87.
# Inserted 2520 records into collection predictions_87.
# Inserted 2538 records into collection predictions_87.
# Inserted 2556 records into collection predictions_87.
# Inserted 2574 records into collection predictions_87.
# Inserted 2592 records into collection predictions_87.
# Inserted 2610 records into collection predictions_87.
# Inserted 2628 records into collection predictions_87.
# Inserted 2646 records into collection predictions_87.
# Inserted 2664 records into collection predictions_87.
# Inserted 2682 records into collection predictions_87.
# Inserted 2700 records into collection predictions_87.
# Inserted 2718 records into collection predictions_87.
# Inserted 2736 records into collection predictions_87.
# Inserted 2754 records into collection predictions_87.
# Inserted 2772 records into collection predictions_87.
# Inserted 2790 records into collection predictions_87.
# Inserted 2808 records into collection predictions_87.
# Inserted 2826 records into collection predictions_87.
# Inserted 2844 records into collection predictions_87.
# Inserted 2862 records into collection predictions_87.
# Inserted 2880 records into collection predictions_87.
# Inserted 2898 records into collection predictions_87.
# Inserted 2916 records into collection predictions_87.
# Inserted 2934 records into collection predictions_87.
# Inserted 2952 records into collection predictions_87.
# Inserted 2970 records into collection predictions_87.
# Inserted 2988 records into collection predictions_87.
# Inserted 3006 records into collection predictions_87.
# Inserted 3024 records into collection predictions_87.
# Inserted 3042 records into collection predictions_87.
# Inserted 3060 records into collection predictions_87.
# Inserted 3078 records into collection predictions_87.
# Inserted 3096 records into collection predictions_87.
# Inserted 3114 records into collection predictions_87.
# Inserted 3132 records into collection predictions_87.
# Inserted 3150 records into collection predictions_87.
# Inserted 3168 records into collection predictions_87.
# Inserted 3186 records into collection predictions_87.
# Inserted 3204 records into collection predictions_87.
# Inserted 3222 records into collection predictions_87.
# Inserted 3240 records into collection predictions_87.
# Inserted 3258 records into collection predictions_87.
# Inserted 3276 records into collection predictions_87.
# Inserted 3294 records into collection predictions_87.
# Inserted 3312 records into collection predictions_87.
# Inserted 3330 records into collection predictions_87.
# Inserted 3348 records into collection predictions_87.
# Inserted 3366 records into collection predictions_87.
# Inserted 3384 records into collection predictions_87.
# Inserted 3402 records into collection predictions_87.
# Inserted 3420 records into collection predictions_87.
# Inserted 3438 records into collection predictions_87.
# Inserted 3456 records into collection predictions_87.
# Inserted 3474 records into collection predictions_87.
# Inserted 3492 records into collection predictions_87.
# Inserted 3510 records into collection predictions_87.
# Inserted 3528 records into collection predictions_87.
# Inserted 3546 records into collection predictions_87.
# Inserted 3564 records into collection predictions_87.
# Inserted 3582 records into collection predictions_87.
# Inserted 3600 records into collection predictions_87.
# Inserted 3618 records into collection predictions_87.
# Inserted 3636 records into collection predictions_87.
# Inserted 3654 records into collection predictions_87.
# Inserted 3672 records into collection predictions_87.
# Inserted 3690 records into collection predictions_87.
# Inserted 3708 records into collection predictions_87.
# Inserted 3726 records into collection predictions_87.
# Inserted 3744 records into collection predictions_87.
# Inserted 3762 records into collection predictions_87.
# Inserted 3780 records into collection predictions_87.
# Inserted 3798 records into collection predictions_87.
# Inserted 3816 records into collection predictions_87.
# Inserted 3834 records into collection predictions_87.
# Inserted 3852 records into collection predictions_87.
# Inserted 3870 records into collection predictions_87.
# Inserted 3888 records into collection predictions_87.
# Inserted 3906 records into collection predictions_87.
# Inserted 3924 records into collection predictions_87.
# Inserted 3942 records into collection predictions_87.
# Inserted 3960 records into collection predictions_87.
# Inserted 3978 records into collection predictions_87.
# Inserted 3996 records into collection predictions_87.
# Inserted 4014 records into collection predictions_87.
# Inserted 4032 records into collection predictions_87.
# Inserted 4050 records into collection predictions_87.
# Inserted 4068 records into collection predictions_87.
# Inserted 4086 records into collection predictions_87.
# Inserted 4104 records into collection predictions_87.
# Inserted 4122 records into collection predictions_87.
# Inserted 4140 records into collection predictions_87.
# Inserted 4158 records into collection predictions_87.
# Inserted 4176 records into collection predictions_87.
# Inserted 4194 records into collection predictions_87.
# Inserted 4212 records into collection predictions_87.
# Inserted 4230 records into collection predictions_87.
# Inserted 4248 records into collection predictions_87.
# Inserted 4266 records into collection predictions_87.
# Inserted 4284 records into collection predictions_87.
# Inserted 4302 records into collection predictions_87.
# Inserted 4320 records into collection predictions_87.
# Inserted 4338 records into collection predictions_87.
# Inserted 4356 records into collection predictions_87.
# Inserted 4374 records into collection predictions_87.
# Inserted 4392 records into collection predictions_87.
# Inserted 4410 records into collection predictions_87.
# Inserted 4428 records into collection predictions_87.
# Inserted 4446 records into collection predictions_87.
# Inserted 4464 records into collection predictions_87.
# Inserted 4482 records into collection predictions_87.
# Inserted 4500 records into collection predictions_87.
# Inserted 4518 records into collection predictions_87.
# Inserted 4536 records into collection predictions_87.
# Inserted 4554 records into collection predictions_87.
# Inserted 4572 records into collection predictions_87.
# Inserted 4590 records into collection predictions_87.
# Inserted 4608 records into collection predictions_87.
# Inserted 4626 records into collection predictions_87.
# Inserted 4644 records into collection predictions_87.
# Inserted 4662 records into collection predictions_87.
# Inserted 4680 records into collection predictions_87.
# Inserted 4698 records into collection predictions_87.
# Inserted 4716 records into collection predictions_87.
# Inserted 4734 records into collection predictions_87.
# Inserted 4752 records into collection predictions_87.
# Inserted 4770 records into collection predictions_87.
# Inserted 4788 records into collection predictions_87.
# Inserted 4806 records into collection predictions_87.
# Inserted 4824 records into collection predictions_87.
# Inserted 4842 records into collection predictions_87.
# Inserted 4860 records into collection predictions_87.
# Inserted 4878 records into collection predictions_87.
# Inserted 4896 records into collection predictions_87.
# Inserted 4914 records into collection predictions_87.
# Inserted 4932 records into collection predictions_87.
# Inserted 4950 records into collection predictions_87.
# Inserted 4968 records into collection predictions_87.
# Inserted 4986 records into collection predictions_87.
# Inserted 5004 records into collection predictions_87.
# Inserted 5022 records into collection predictions_87.
# Inserted 5040 records into collection predictions_87.
# Inserted 5058 records into collection predictions_87.
# Inserted 5076 records into collection predictions_87.
# Inserted 5094 records into collection predictions_87.
# Inserted 5112 records into collection predictions_87.
# Inserted 5130 records into collection predictions_87.
# Inserted 5148 records into collection predictions_87.
# Inserted 5166 records into collection predictions_87.
# Inserted 5184 records into collection predictions_87.
# Inserted 5202 records into collection predictions_87.
# Inserted 5220 records into collection predictions_87.
# Inserted 5238 records into collection predictions_87.
# Inserted 5256 records into collection predictions_87.
# Inserted 5274 records into collection predictions_87.
# Inserted 5292 records into collection predictions_87.
# Inserted 5310 records into collection predictions_87.
# Inserted 5328 records into collection predictions_87.
# Inserted 5346 records into collection predictions_87.
# Inserted 5364 records into collection predictions_87.
# Inserted 5382 records into collection predictions_87.
# Inserted 5400 records into collection predictions_87.
# Inserted 5418 records into collection predictions_87.
# Inserted 5436 records into collection predictions_87.
# Inserted 5454 records into collection predictions_87.
# Inserted 5472 records into collection predictions_87.
# Inserted 5490 records into collection predictions_87.
# Inserted 5508 records into collection predictions_87.
# Inserted 5526 records into collection predictions_87.
# Inserted 5544 records into collection predictions_87.
# Inserted 5562 records into collection predictions_87.
# Inserted 5580 records into collection predictions_87.
# Inserted 5598 records into collection predictions_87.
# Inserted 5616 records into collection predictions_87.
# Inserted 5634 records into collection predictions_87.
# Inserted 5652 records into collection predictions_87.
# Inserted 5670 records into collection predictions_87.
# Inserted 5688 records into collection predictions_87.
# Inserted 5706 records into collection predictions_87.
# Inserted 5724 records into collection predictions_87.
# Inserted 5742 records into collection predictions_87.
# Inserted 5760 records into collection predictions_87.
# Inserted 5778 records into collection predictions_87.
# Inserted 5796 records into collection predictions_87.
# Inserted 5814 records into collection predictions_87.
# Inserted 5832 records into collection predictions_87.
# Inserted 5850 records into collection predictions_87.
# Inserted 5868 records into collection predictions_87.
# Inserted 5886 records into collection predictions_87.
# Inserted 5904 records into collection predictions_87.
# Inserted 5922 records into collection predictions_87.
# Inserted 5940 records into collection predictions_87.
# Inserted 5958 records into collection predictions_87.
# Inserted 5976 records into collection predictions_87.
# Inserted 5994 records into collection predictions_87.
# Inserted 6012 records into collection predictions_87.
# Inserted 6030 records into collection predictions_87.
# Inserted 6048 records into collection predictions_87.
# Inserted 6066 records into collection predictions_87.
# Inserted 6084 records into collection predictions_87.
# Inserted 6102 records into collection predictions_87.
# Inserted 6120 records into collection predictions_87.
# Inserted 6138 records into collection predictions_87.
# Inserted 6156 records into collection predictions_87.
# Inserted 6174 records into collection predictions_87.
# Inserted 6192 records into collection predictions_87.
# Inserted 6210 records into collection predictions_87.
# Inserted 6228 records into collection predictions_87.
# Inserted 6246 records into collection predictions_87.
# Inserted 6264 records into collection predictions_87.
# Inserted 6282 records into collection predictions_87.
# Inserted 6300 records into collection predictions_87.
# Inserted 6318 records into collection predictions_87.
# Inserted 6336 records into collection predictions_87.
# Inserted 6354 records into collection predictions_87.
# Inserted 6372 records into collection predictions_87.
# Inserted 6390 records into collection predictions_87.
# Inserted 6408 records into collection predictions_87.
# Inserted 6426 records into collection predictions_87.
# Inserted 6444 records into collection predictions_87.
# Inserted 6462 records into collection predictions_87.
# Inserted 6480 records into collection predictions_87.
# Inserted 6498 records into collection predictions_87.
# Inserted 6516 records into collection predictions_87.
# Inserted 6534 records into collection predictions_87.
# Inserted 6552 records into collection predictions_87.
# Inserted 6570 records into collection predictions_87.
# Inserted 6588 records into collection predictions_87.
# Inserted 6606 records into collection predictions_87.
# Inserted 6624 records into collection predictions_87.
# Inserted 6642 records into collection predictions_87.
# Inserted 6660 records into collection predictions_87.
# Inserted 6678 records into collection predictions_87.
# Inserted 6696 records into collection predictions_87.
# Inserted 6714 records into collection predictions_87.
# Inserted 6732 records into collection predictions_87.
# Inserted 6750 records into collection predictions_87.
# Inserted 6768 records into collection predictions_87.
# Inserted 6786 records into collection predictions_87.
# Inserted 6804 records into collection predictions_87.
# Inserted 6822 records into collection predictions_87.
# Inserted 6840 records into collection predictions_87.
# Inserted 6858 records into collection predictions_87.
# Inserted 6876 records into collection predictions_87.
# Inserted 6894 records into collection predictions_87.
# Inserted 6912 records into collection predictions_87.
# Inserted 6930 records into collection predictions_87.
# Inserted 6948 records into collection predictions_87.
# Inserted 6966 records into collection predictions_87.
# Inserted 6984 records into collection predictions_87.
# Inserted 7002 records into collection predictions_87.
# Inserted 7020 records into collection predictions_87.
# Inserted 7038 records into collection predictions_87.
# Inserted 7056 records into collection predictions_87.
# Inserted 7074 records into collection predictions_87.
# Inserted 7092 records into collection predictions_87.
# Inserted 7110 records into collection predictions_87.
# Inserted 7128 records into collection predictions_87.
# Inserted 7146 records into collection predictions_87.
# Inserted 7164 records into collection predictions_87.
# Inserted 7182 records into collection predictions_87.
# Inserted 7200 records into collection predictions_87.
# Inserted 7218 records into collection predictions_87.
# Inserted 7236 records into collection predictions_87.
# Inserted 7254 records into collection predictions_87.
# Inserted 7272 records into collection predictions_87.
# Inserted 7290 records into collection predictions_87.
# Inserted 7308 records into collection predictions_87.
# Inserted 7326 records into collection predictions_87.
# Inserted 7344 records into collection predictions_87.
# Inserted 7362 records into collection predictions_87.
# Inserted 7380 records into collection predictions_87.
# Inserted 7398 records into collection predictions_87.
# Inserted 7416 records into collection predictions_87.
# Inserted 7434 records into collection predictions_87.
# Inserted 7452 records into collection predictions_87.
# Inserted 7470 records into collection predictions_87.
# Inserted 7488 records into collection predictions_87.
# Inserted 7506 records into collection predictions_87.
# Inserted 7524 records into collection predictions_87.
# Inserted 7542 records into collection predictions_87.
# Inserted 7560 records into collection predictions_87.
# Inserted 7578 records into collection predictions_87.
# Inserted 7596 records into collection predictions_87.
# Inserted 7614 records into collection predictions_87.
# Inserted 7632 records into collection predictions_87.
# Inserted 7650 records into collection predictions_87.
# Inserted 7668 records into collection predictions_87.
# Inserted 7686 records into collection predictions_87.
# Inserted 7704 records into collection predictions_87.
# Inserted 7722 records into collection predictions_87.
# Inserted 7740 records into collection predictions_87.
# Inserted 7758 records into collection predictions_87.
# Inserted 7776 records into collection predictions_87.
# Inserted 7794 records into collection predictions_87.
# Inserted 7812 records into collection predictions_87.
# Inserted 7830 records into collection predictions_87.
# Inserted 7848 records into collection predictions_87.
# Inserted 7866 records into collection predictions_87.
# Inserted 7884 records into collection predictions_87.
# Inserted 7902 records into collection predictions_87.
# Inserted 7920 records into collection predictions_87.
# Inserted 7938 records into collection predictions_87.
# Inserted 7956 records into collection predictions_87.
# Inserted 7974 records into collection predictions_87.
# Inserted 7992 records into collection predictions_87.
# Inserted 8010 records into collection predictions_87.
# Inserted 8028 records into collection predictions_87.
# Inserted 8046 records into collection predictions_87.
# Inserted 8064 records into collection predictions_87.
# Inserted 8082 records into collection predictions_87.
# Inserted 8100 records into collection predictions_87.
# Inserted 8118 records into collection predictions_87.
# Inserted 8136 records into collection predictions_87.
# Inserted 8154 records into collection predictions_87.
# Inserted 8172 records into collection predictions_87.
# Inserted 8190 records into collection predictions_87.
# Inserted 8208 records into collection predictions_87.
# Inserted 8226 records into collection predictions_87.
# Inserted 8244 records into collection predictions_87.
# Inserted 8262 records into collection predictions_87.
# Inserted 8280 records into collection predictions_87.
# Inserted 8298 records into collection predictions_87.
# Inserted 8316 records into collection predictions_87.
# Inserted 8334 records into collection predictions_87.
# Inserted 8352 records into collection predictions_87.
# Inserted 8370 records into collection predictions_87.
# Inserted 8388 records into collection predictions_87.
# Inserted 8406 records into collection predictions_87.
# Inserted 8424 records into collection predictions_87.
# Inserted 8442 records into collection predictions_87.
# Inserted 8460 records into collection predictions_87.
# Inserted 8478 records into collection predictions_87.
# Inserted 8496 records into collection predictions_87.
# Inserted 8514 records into collection predictions_87.
# Inserted 8532 records into collection predictions_87.
# Inserted 8550 records into collection predictions_87.
# Inserted 8568 records into collection predictions_87.
# Inserted 8586 records into collection predictions_87.
# Inserted 8604 records into collection predictions_87.
# Inserted 8622 records into collection predictions_87.
# Inserted 8640 records into collection predictions_87.
# Inserted 8658 records into collection predictions_87.
# Inserted 8676 records into collection predictions_87.
# Inserted 8694 records into collection predictions_87.
# Inserted 8712 records into collection predictions_87.
# Inserted 8730 records into collection predictions_87.
# Inserted 8748 records into collection predictions_87.
# Inserted 8766 records into collection predictions_87.
# Inserted 8784 records into collection predictions_87.
# Inserted 8802 records into collection predictions_87.
# Inserted 8820 records into collection predictions_87.
# Inserted 8838 records into collection predictions_87.
# Inserted 8856 records into collection predictions_87.
# Inserted 8874 records into collection predictions_87.
# Inserted 8892 records into collection predictions_87.
# Inserted 8910 records into collection predictions_87.
# Inserted 8928 records into collection predictions_87.
# Inserted 8946 records into collection predictions_87.
# Inserted 8964 records into collection predictions_87.
# Inserted 8982 records into collection predictions_87.
# Inserted 9000 records into collection predictions_87.
# Inserted 9018 records into collection predictions_87.
# Inserted 9036 records into collection predictions_87.
# Inserted 9054 records into collection predictions_87.
# Inserted 9072 records into collection predictions_87.
# Inserted 9090 records into collection predictions_87.
# Inserted 9108 records into collection predictions_87.
# Inserted 9126 records into collection predictions_87.
# Inserted 9144 records into collection predictions_87.
# Inserted 9162 records into collection predictions_87.
# Inserted 9180 records into collection predictions_87.
# Inserted 9198 records into collection predictions_87.
# Inserted 9216 records into collection predictions_87.
# Inserted 9234 records into collection predictions_87.
# Inserted 9252 records into collection predictions_87.
# Inserted 9270 records into collection predictions_87.
# Inserted 9288 records into collection predictions_87.
# Inserted 9306 records into collection predictions_87.
# Inserted 9324 records into collection predictions_87.
# Inserted 9342 records into collection predictions_87.
# Inserted 9360 records into collection predictions_87.
# Inserted 9378 records into collection predictions_87.
# Inserted 9396 records into collection predictions_87.
# Inserted 9414 records into collection predictions_87.
# Inserted 9432 records into collection predictions_87.
# Inserted 9450 records into collection predictions_87.
# Inserted 9468 records into collection predictions_87.
# Inserted 9486 records into collection predictions_87.
# Inserted 9504 records into collection predictions_87.
# Inserted 9522 records into collection predictions_87.
# Inserted 9540 records into collection predictions_87.
# Inserted 9558 records into collection predictions_87.
# Inserted 9576 records into collection predictions_87.
# Inserted 9594 records into collection predictions_87.
# Inserted 9612 records into collection predictions_87.
# Inserted 9630 records into collection predictions_87.
# Inserted 9648 records into collection predictions_87.
# Inserted 9666 records into collection predictions_87.
# Inserted 9684 records into collection predictions_87.
# Inserted 9702 records into collection predictions_87.
# Inserted 9720 records into collection predictions_87.
# Inserted 9738 records into collection predictions_87.
# Inserted 9756 records into collection predictions_87.
# Inserted 9774 records into collection predictions_87.
# Inserted 9792 records into collection predictions_87.
# Inserted 9810 records into collection predictions_87.
# Inserted 9828 records into collection predictions_87.
# Inserted 9846 records into collection predictions_87.
# Inserted 9864 records into collection predictions_87.
# Inserted 9882 records into collection predictions_87.
# Inserted 9900 records into collection predictions_87.
# Inserted 9918 records into collection predictions_87.
# Inserted 9936 records into collection predictions_87.
# Inserted 9954 records into collection predictions_87.
# Inserted 9972 records into collection predictions_87.
# Inserted 9990 records into collection predictions_87.
# Inserted 10008 records into collection predictions_87.
# Inserted 10026 records into collection predictions_87.
# Inserted 10044 records into collection predictions_87.
# Inserted 10062 records into collection predictions_87.
# Inserted 10080 records into collection predictions_87.
# Inserted 10098 records into collection predictions_87.
# Inserted 10116 records into collection predictions_87.
# Inserted 10134 records into collection predictions_87.
# Inserted 10152 records into collection predictions_87.
# Inserted 10170 records into collection predictions_87.
# Inserted 10188 records into collection predictions_87.
# Inserted 10206 records into collection predictions_87.
# Inserted 10224 records into collection predictions_87.
# Inserted 10242 records into collection predictions_87.
# Inserted 10260 records into collection predictions_87.
# Inserted 10278 records into collection predictions_87.
# Inserted 10296 records into collection predictions_87.
# Inserted 10314 records into collection predictions_87.
# Inserted 10332 records into collection predictions_87.
# Inserted 10350 records into collection predictions_87.
# Inserted 10368 records into collection predictions_87.
# Inserted 10386 records into collection predictions_87.
# Inserted 10404 records into collection predictions_87.
# Inserted 10422 records into collection predictions_87.
# Inserted 10440 records into collection predictions_87.
# Inserted 10458 records into collection predictions_87.
# Inserted 10476 records into collection predictions_87.
# Inserted 10494 records into collection predictions_87.
# Inserted 10512 records into collection predictions_87.
# Inserted 10530 records into collection predictions_87.
# Inserted 10548 records into collection predictions_87.
# Inserted 10566 records into collection predictions_87.
# Inserted 10584 records into collection predictions_87.
# Inserted 10602 records into collection predictions_87.
# Inserted 10620 records into collection predictions_87.
# Inserted 10638 records into collection predictions_87.
# Inserted 10656 records into collection predictions_87.
# Inserted 10674 records into collection predictions_87.
# Inserted 10692 records into collection predictions_87.
# Inserted 10710 records into collection predictions_87.
# Inserted 10728 records into collection predictions_87.
# Inserted 10746 records into collection predictions_87.
# Inserted 10764 records into collection predictions_87.
# Inserted 10782 records into collection predictions_87.
# Inserted 10800 records into collection predictions_87.
# Inserted 10818 records into collection predictions_87.
# Inserted 10836 records into collection predictions_87.
# Inserted 10854 records into collection predictions_87.
# Inserted 10872 records into collection predictions_87.
# Inserted 10890 records into collection predictions_87.
# Inserted 10908 records into collection predictions_87.
# Inserted 10926 records into collection predictions_87.
# Inserted 10944 records into collection predictions_87.
# Inserted 10962 records into collection predictions_87.
# Inserted 10980 records into collection predictions_87.
# Inserted 10998 records into collection predictions_87.
# Inserted 11016 records into collection predictions_87.
# Inserted 11034 records into collection predictions_87.
# Inserted 11052 records into collection predictions_87.
# Inserted 11070 records into collection predictions_87.
# Inserted 11088 records into collection predictions_87.
# Inserted 11106 records into collection predictions_87.
# Inserted 11124 records into collection predictions_87.
# Inserted 11142 records into collection predictions_87.
# Inserted 11160 records into collection predictions_87.
# Inserted 11178 records into collection predictions_87.
# Inserted 11196 records into collection predictions_87.
# Inserted 11214 records into collection predictions_87.
# Inserted 11232 records into collection predictions_87.
# Inserted 11250 records into collection predictions_87.
# Inserted 11268 records into collection predictions_87.
# Inserted 11286 records into collection predictions_87.
# Inserted 11304 records into collection predictions_87.
# Inserted 11322 records into collection predictions_87.
# Inserted 11340 records into collection predictions_87.
# Inserted 11358 records into collection predictions_87.
# Inserted 11376 records into collection predictions_87.
# Inserted 11394 records into collection predictions_87.
# Inserted 11412 records into collection predictions_87.
# Inserted 11430 records into collection predictions_87.
# Inserted 11448 records into collection predictions_87.
# Inserted 11466 records into collection predictions_87.
# Inserted 11484 records into collection predictions_87.
# Inserted 11502 records into collection predictions_87.
# Inserted 11520 records into collection predictions_87.
# Inserted 11538 records into collection predictions_87.
# Inserted 11556 records into collection predictions_87.
# Inserted 11574 records into collection predictions_87.
# Inserted 11592 records into collection predictions_87.
# Inserted 11610 records into collection predictions_87.
# Inserted 11628 records into collection predictions_87.
# Inserted 11646 records into collection predictions_87.

# %%
print(f"Failed batches: {fails}")
# Out:
# Failed batches: []

# %%
index = {
    "index_type": "IVF_FLAT",
    "metric_type": "L2",
    "params": {"nlist": 128},
}
collection.create_index(field_name="predictions", index_params=index)
# Out:
# Status(code=0, message=)

# %%
collection.load()

# %%
random_song = pick_random_mp3(DATASET).with_suffix(".pkl")
print(f"Random mp3: {random_song}")
print(get_top_5_genres(random_song, "utils/mtg_jamendo_genre.json"))

with open(random_song, "rb") as f:
    file_info = pickle.load(f)
    query_embed = file_info.get("predictions_87")
    
search_params = {"metric_type": "L2", "params": {"nprobe": 10}}
result = collection.search([query_embed], "predictions", search_params, limit=10,offset=1, output_fields=["path"])
print('\n')
for element in result[0]:
    print(element)
# Out:
# Random mp3: MegaSet/Casualty/Casualty - Version 5_2 (2008)/008_casualty_-_bad_dreams.pkl
# ['reggae', 'electronic', 'dub', 'experimental', 'alternative']
#
#
# id: 2288, distance: 0.012982561253011227, entity: {'path': 'MegaSet/High Tone/High Tone-Bass Temperature/Piste 11 [2].mp3'}
# id: 2252, distance: 0.014431831426918507, entity: {'path': 'MegaSet/High Tone/Hight Tone & Improvisators Dub - Highvisators - 100% Dub/06. U-Man Bass.mp3'}
# id: 2283, distance: 0.014883620664477348, entity: {'path': 'MegaSet/High Tone/High Tone-Bass Temperature/Piste 05 [2].mp3'}
# id: 6164, distance: 0.016342703253030777, entity: {'path': 'MegaSet/Jah Shaka meets Mad Professor - At Ariwa Sounds (1996)/09. Living Dub.mp3'}
# id: 10296, distance: 0.020877933129668236, entity: {'path': 'MegaSet/The Black Seeds/The Black Seeds - [2008] Solid Ground/13-the_black_seeds--make_a_move_dub-oma.mp3'}
# id: 6134, distance: 0.021576734259724617, entity: {'path': 'MegaSet/Casualty/Casualty - Version 5_2 (2008)/009_casualty_-_diablo_manus.mp3'}
# id: 4749, distance: 0.02171768993139267, entity: {'path': 'MegaSet/Clinton Fearon/Clinton Fearon - 2008 - Faculty Of Dub/08-clinton_fearon-get_out.mp3'}
# id: 7527, distance: 0.021827619522809982, entity: {'path': 'MegaSet/UB40/UB40 - 1998 - Labour of love III/15 - Legalise it.mp3'}
# id: 5679, distance: 0.02216803841292858, entity: {'path': 'MegaSet/M_I_A/M_I_A_ - 2013 - Matangi/01 - M.I.A - Karmageddon.mp3'}
# id: 6170, distance: 0.02232038602232933, entity: {'path': 'MegaSet/Jah Shaka meets Mad Professor - At Ariwa Sounds (1996)/08. Warrior Dub.mp3'}

# %%
########## embedding_512 ##########

# %%
print(utility.list_collections())
# Out:
# ['predictions_87', 'embeddings_512']

# %%
# Check if the collection exists
check_collection_name = 'embeddings_512'

check_collection = utility.has_collection(check_collection_name )
if check_collection:
    drop_result = utility.drop_collection(check_collection_name )

print(utility.list_collections())
# Out:
# ['predictions_87']

# %%
# create a collection for embeddings_512
collection_name = "embeddings_512"
dimension = 512

# Define the schema
schema = CollectionSchema(
    fields=[
        FieldSchema(name="id",dtype=DataType.INT64,is_primary=True,auto_id=False,max_length=100),
        FieldSchema(name="path", dtype=DataType.VARCHAR, max_length=280),
        FieldSchema(name="title", dtype=DataType.VARCHAR, max_length=220),
        FieldSchema(name="album", dtype=DataType.VARCHAR, max_length=240),
        FieldSchema(name="artist", dtype=DataType.VARCHAR, max_length=120),
        FieldSchema(name="embedding", dtype=DataType.FLOAT_VECTOR, dim=dimension),
        FieldSchema(name="top_5_genres",dtype=DataType.ARRAY,element_type=DataType.VARCHAR,max_capacity=5,max_length=100),
    ],
    enable_dynamic_field=True,  # Optional, defaults to 'False'.
)

print(f"Creating example collection: {collection_name}")
collection = Collection(collection_name, schema)
print(f"Schema: {schema}")
print("Success!")
# Out:
# Creating example collection: embeddings_512
# Schema: {'auto_id': False, 'description': '', 'fields': [{'name': 'id', 'description': '', 'type': <DataType.INT64: 5>, 'is_primary': True, 'auto_id': False}, {'name': 'path', 'description': '', 'type': <DataType.VARCHAR: 21>, 'params': {'max_length': 280}}, {'name': 'title', 'description': '', 'type': <DataType.VARCHAR: 21>, 'params': {'max_length': 220}}, {'name': 'album', 'description': '', 'type': <DataType.VARCHAR: 21>, 'params': {'max_length': 240}}, {'name': 'artist', 'description': '', 'type': <DataType.VARCHAR: 21>, 'params': {'max_length': 120}}, {'name': 'embedding', 'description': '', 'type': <DataType.FLOAT_VECTOR: 101>, 'params': {'dim': 512}}, {'name': 'top_5_genres', 'description': '', 'type': <DataType.ARRAY: 22>, 'params': {'max_length': 100, 'max_capacity': 5}, 'element_type': <DataType.VARCHAR: 21>}], 'enable_dynamic_field': True}
# Success!

# %%
def process_file(args):
    i, path = args
    try:
        with open(path, "rb") as f:
            data = pickle.load(f)
            filepath = data.get("filepath")
            title = data.get("title")
            album = data.get("album")
            artist = data.get("artist")
            predictions = data.get("embedding_512") #
            top_5_genres = data.get("top_5_genres")

        if isinstance(predictions, np.ndarray):
            return (i, filepath, title, album, artist, predictions, top_5_genres)
    except Exception as e:
        logging.error(f"Error processing file {path}: {str(e)}")
        return None

# %%
# Use a multiprocessing pool to process the files in parallel
with Pool() as p:
    results = p.map(process_file, enumerate(pkl_files))

# Filter out None results
results = [r for r in results if r is not None]

# Batch size
batch_size = 18

fails = []

# Insert the data into the collection
for i in range(0, len(results), batch_size):
    id_batch, path_batch, title_batch, album_batch, artist_batch, embeddings_batch, top_5_genres_batch = zip(*results[i : i + batch_size])
    documents = [
        {
            "id": id,
            "path": path,
            "title": title,
            "album": album,
            "artist": artist,
            "embedding": embeddings.tolist(),
            "top_5_genres": top_5_genres
        }
        for id, path, title, album, artist, embeddings, top_5_genres in zip(
            id_batch, path_batch, title_batch, album_batch, artist_batch, embeddings_batch, top_5_genres_batch,
        )
    ]
    try:
        collection.insert(documents)
        print(f"Inserted {i + batch_size} records into collection {collection.name}.")
    except Exception as e:
        fails.append((i + batch_size, documents))
        print(f"Error inserting batch {i + batch_size} into collection {collection.name}. Error: {str(e)}")

# 2m 28.2s
# Out:
# Inserted 18 records into collection embeddings_512.
# Inserted 36 records into collection embeddings_512.
# Inserted 54 records into collection embeddings_512.
# Inserted 72 records into collection embeddings_512.
# Inserted 90 records into collection embeddings_512.
# Inserted 108 records into collection embeddings_512.
# Inserted 126 records into collection embeddings_512.
# Inserted 144 records into collection embeddings_512.
# Inserted 162 records into collection embeddings_512.
# Inserted 180 records into collection embeddings_512.
# Inserted 198 records into collection embeddings_512.
# Inserted 216 records into collection embeddings_512.
# Inserted 234 records into collection embeddings_512.
# Inserted 252 records into collection embeddings_512.
# Inserted 270 records into collection embeddings_512.
# Inserted 288 records into collection embeddings_512.
# Inserted 306 records into collection embeddings_512.
# Inserted 324 records into collection embeddings_512.
# Inserted 342 records into collection embeddings_512.
# Inserted 360 records into collection embeddings_512.
# Inserted 378 records into collection embeddings_512.
# Inserted 396 records into collection embeddings_512.
# Inserted 414 records into collection embeddings_512.
# Inserted 432 records into collection embeddings_512.
# Inserted 450 records into collection embeddings_512.
# Inserted 468 records into collection embeddings_512.
# Inserted 486 records into collection embeddings_512.
# Inserted 504 records into collection embeddings_512.
# Inserted 522 records into collection embeddings_512.
# Inserted 540 records into collection embeddings_512.
# Inserted 558 records into collection embeddings_512.
# Inserted 576 records into collection embeddings_512.
# Inserted 594 records into collection embeddings_512.
# Inserted 612 records into collection embeddings_512.
# Inserted 630 records into collection embeddings_512.
# Inserted 648 records into collection embeddings_512.
# Inserted 666 records into collection embeddings_512.
# Inserted 684 records into collection embeddings_512.
# Inserted 702 records into collection embeddings_512.
# Inserted 720 records into collection embeddings_512.
# Inserted 738 records into collection embeddings_512.
# Inserted 756 records into collection embeddings_512.
# Inserted 774 records into collection embeddings_512.
# Inserted 792 records into collection embeddings_512.
# Inserted 810 records into collection embeddings_512.
# Inserted 828 records into collection embeddings_512.
# Inserted 846 records into collection embeddings_512.
# Inserted 864 records into collection embeddings_512.
# Inserted 882 records into collection embeddings_512.
# Inserted 900 records into collection embeddings_512.
# Inserted 918 records into collection embeddings_512.
# Inserted 936 records into collection embeddings_512.
# Inserted 954 records into collection embeddings_512.
# Inserted 972 records into collection embeddings_512.
# Inserted 990 records into collection embeddings_512.
# Inserted 1008 records into collection embeddings_512.
# Inserted 1026 records into collection embeddings_512.
# Inserted 1044 records into collection embeddings_512.
# Inserted 1062 records into collection embeddings_512.
# Inserted 1080 records into collection embeddings_512.
# Inserted 1098 records into collection embeddings_512.
# Inserted 1116 records into collection embeddings_512.
# Inserted 1134 records into collection embeddings_512.
# Inserted 1152 records into collection embeddings_512.
# Inserted 1170 records into collection embeddings_512.
# Inserted 1188 records into collection embeddings_512.
# Inserted 1206 records into collection embeddings_512.
# Inserted 1224 records into collection embeddings_512.
# Inserted 1242 records into collection embeddings_512.
# Inserted 1260 records into collection embeddings_512.
# Inserted 1278 records into collection embeddings_512.
# Inserted 1296 records into collection embeddings_512.
# Inserted 1314 records into collection embeddings_512.
# Inserted 1332 records into collection embeddings_512.
# Inserted 1350 records into collection embeddings_512.
# Inserted 1368 records into collection embeddings_512.
# Inserted 1386 records into collection embeddings_512.
# Inserted 1404 records into collection embeddings_512.
# Inserted 1422 records into collection embeddings_512.
# Inserted 1440 records into collection embeddings_512.
# Inserted 1458 records into collection embeddings_512.
# Inserted 1476 records into collection embeddings_512.
# Inserted 1494 records into collection embeddings_512.
# Inserted 1512 records into collection embeddings_512.
# Inserted 1530 records into collection embeddings_512.
# Inserted 1548 records into collection embeddings_512.
# Inserted 1566 records into collection embeddings_512.
# Inserted 1584 records into collection embeddings_512.
# Inserted 1602 records into collection embeddings_512.
# Inserted 1620 records into collection embeddings_512.
# Inserted 1638 records into collection embeddings_512.
# Inserted 1656 records into collection embeddings_512.
# Inserted 1674 records into collection embeddings_512.
# Inserted 1692 records into collection embeddings_512.
# Inserted 1710 records into collection embeddings_512.
# Inserted 1728 records into collection embeddings_512.
# Inserted 1746 records into collection embeddings_512.
# Inserted 1764 records into collection embeddings_512.
# Inserted 1782 records into collection embeddings_512.
# Inserted 1800 records into collection embeddings_512.
# Inserted 1818 records into collection embeddings_512.
# Inserted 1836 records into collection embeddings_512.
# Inserted 1854 records into collection embeddings_512.
# Inserted 1872 records into collection embeddings_512.
# Inserted 1890 records into collection embeddings_512.
# Inserted 1908 records into collection embeddings_512.
# Inserted 1926 records into collection embeddings_512.
# Inserted 1944 records into collection embeddings_512.
# Inserted 1962 records into collection embeddings_512.
# Inserted 1980 records into collection embeddings_512.
# Inserted 1998 records into collection embeddings_512.
# Inserted 2016 records into collection embeddings_512.
# Inserted 2034 records into collection embeddings_512.
# Inserted 2052 records into collection embeddings_512.
# Inserted 2070 records into collection embeddings_512.
# Inserted 2088 records into collection embeddings_512.
# Inserted 2106 records into collection embeddings_512.
# Inserted 2124 records into collection embeddings_512.
# Inserted 2142 records into collection embeddings_512.
# Inserted 2160 records into collection embeddings_512.
# Inserted 2178 records into collection embeddings_512.
# Inserted 2196 records into collection embeddings_512.
# Inserted 2214 records into collection embeddings_512.
# Inserted 2232 records into collection embeddings_512.
# Inserted 2250 records into collection embeddings_512.
# Inserted 2268 records into collection embeddings_512.
# Inserted 2286 records into collection embeddings_512.
# Inserted 2304 records into collection embeddings_512.
# Inserted 2322 records into collection embeddings_512.
# Inserted 2340 records into collection embeddings_512.
# Inserted 2358 records into collection embeddings_512.
# Inserted 2376 records into collection embeddings_512.
# Inserted 2394 records into collection embeddings_512.
# Inserted 2412 records into collection embeddings_512.
# Inserted 2430 records into collection embeddings_512.
# Inserted 2448 records into collection embeddings_512.
# Inserted 2466 records into collection embeddings_512.
# Inserted 2484 records into collection embeddings_512.
# Inserted 2502 records into collection embeddings_512.
# Inserted 2520 records into collection embeddings_512.
# Inserted 2538 records into collection embeddings_512.
# Inserted 2556 records into collection embeddings_512.
# Inserted 2574 records into collection embeddings_512.
# Inserted 2592 records into collection embeddings_512.
# Inserted 2610 records into collection embeddings_512.
# Inserted 2628 records into collection embeddings_512.
# Inserted 2646 records into collection embeddings_512.
# Inserted 2664 records into collection embeddings_512.
# Inserted 2682 records into collection embeddings_512.
# Inserted 2700 records into collection embeddings_512.
# Inserted 2718 records into collection embeddings_512.
# Inserted 2736 records into collection embeddings_512.
# Inserted 2754 records into collection embeddings_512.
# Inserted 2772 records into collection embeddings_512.
# Inserted 2790 records into collection embeddings_512.
# Inserted 2808 records into collection embeddings_512.
# Inserted 2826 records into collection embeddings_512.
# Inserted 2844 records into collection embeddings_512.
# Inserted 2862 records into collection embeddings_512.
# Inserted 2880 records into collection embeddings_512.
# Inserted 2898 records into collection embeddings_512.
# Inserted 2916 records into collection embeddings_512.
# Inserted 2934 records into collection embeddings_512.
# Inserted 2952 records into collection embeddings_512.
# Inserted 2970 records into collection embeddings_512.
# Inserted 2988 records into collection embeddings_512.
# Inserted 3006 records into collection embeddings_512.
# Inserted 3024 records into collection embeddings_512.
# Inserted 3042 records into collection embeddings_512.
# Inserted 3060 records into collection embeddings_512.
# Inserted 3078 records into collection embeddings_512.
# Inserted 3096 records into collection embeddings_512.
# Inserted 3114 records into collection embeddings_512.
# Inserted 3132 records into collection embeddings_512.
# Inserted 3150 records into collection embeddings_512.
# Inserted 3168 records into collection embeddings_512.
# Inserted 3186 records into collection embeddings_512.
# Inserted 3204 records into collection embeddings_512.
# Inserted 3222 records into collection embeddings_512.
# Inserted 3240 records into collection embeddings_512.
# Inserted 3258 records into collection embeddings_512.
# Inserted 3276 records into collection embeddings_512.
# Inserted 3294 records into collection embeddings_512.
# Inserted 3312 records into collection embeddings_512.
# Inserted 3330 records into collection embeddings_512.
# Inserted 3348 records into collection embeddings_512.
# Inserted 3366 records into collection embeddings_512.
# Inserted 3384 records into collection embeddings_512.
# Inserted 3402 records into collection embeddings_512.
# Inserted 3420 records into collection embeddings_512.
# Inserted 3438 records into collection embeddings_512.
# Inserted 3456 records into collection embeddings_512.
# Inserted 3474 records into collection embeddings_512.
# Inserted 3492 records into collection embeddings_512.
# Inserted 3510 records into collection embeddings_512.
# Inserted 3528 records into collection embeddings_512.
# Inserted 3546 records into collection embeddings_512.
# Inserted 3564 records into collection embeddings_512.
# Inserted 3582 records into collection embeddings_512.
# Inserted 3600 records into collection embeddings_512.
# Inserted 3618 records into collection embeddings_512.
# Inserted 3636 records into collection embeddings_512.
# Inserted 3654 records into collection embeddings_512.
# Inserted 3672 records into collection embeddings_512.
# Inserted 3690 records into collection embeddings_512.
# Inserted 3708 records into collection embeddings_512.
# Inserted 3726 records into collection embeddings_512.
# Inserted 3744 records into collection embeddings_512.
# Inserted 3762 records into collection embeddings_512.
# Inserted 3780 records into collection embeddings_512.
# Inserted 3798 records into collection embeddings_512.
# Inserted 3816 records into collection embeddings_512.
# Inserted 3834 records into collection embeddings_512.
# Inserted 3852 records into collection embeddings_512.
# Inserted 3870 records into collection embeddings_512.
# Inserted 3888 records into collection embeddings_512.
# Inserted 3906 records into collection embeddings_512.
# Inserted 3924 records into collection embeddings_512.
# Inserted 3942 records into collection embeddings_512.
# Inserted 3960 records into collection embeddings_512.
# Inserted 3978 records into collection embeddings_512.
# Inserted 3996 records into collection embeddings_512.
# Inserted 4014 records into collection embeddings_512.
# Inserted 4032 records into collection embeddings_512.
# Inserted 4050 records into collection embeddings_512.
# Inserted 4068 records into collection embeddings_512.
# Inserted 4086 records into collection embeddings_512.
# Inserted 4104 records into collection embeddings_512.
# Inserted 4122 records into collection embeddings_512.
# Inserted 4140 records into collection embeddings_512.
# Inserted 4158 records into collection embeddings_512.
# Inserted 4176 records into collection embeddings_512.
# Inserted 4194 records into collection embeddings_512.
# Inserted 4212 records into collection embeddings_512.
# Inserted 4230 records into collection embeddings_512.
# Inserted 4248 records into collection embeddings_512.
# Inserted 4266 records into collection embeddings_512.
# Inserted 4284 records into collection embeddings_512.
# Inserted 4302 records into collection embeddings_512.
# Inserted 4320 records into collection embeddings_512.
# Inserted 4338 records into collection embeddings_512.
# Inserted 4356 records into collection embeddings_512.
# Inserted 4374 records into collection embeddings_512.
# Inserted 4392 records into collection embeddings_512.
# Inserted 4410 records into collection embeddings_512.
# Inserted 4428 records into collection embeddings_512.
# Inserted 4446 records into collection embeddings_512.
# Inserted 4464 records into collection embeddings_512.
# Inserted 4482 records into collection embeddings_512.
# Inserted 4500 records into collection embeddings_512.
# Inserted 4518 records into collection embeddings_512.
# Inserted 4536 records into collection embeddings_512.
# Inserted 4554 records into collection embeddings_512.
# Inserted 4572 records into collection embeddings_512.
# Inserted 4590 records into collection embeddings_512.
# Inserted 4608 records into collection embeddings_512.
# Inserted 4626 records into collection embeddings_512.
# Inserted 4644 records into collection embeddings_512.
# Inserted 4662 records into collection embeddings_512.
# Inserted 4680 records into collection embeddings_512.
# Inserted 4698 records into collection embeddings_512.
# Inserted 4716 records into collection embeddings_512.
# Inserted 4734 records into collection embeddings_512.
# Inserted 4752 records into collection embeddings_512.
# Inserted 4770 records into collection embeddings_512.
# Inserted 4788 records into collection embeddings_512.
# Inserted 4806 records into collection embeddings_512.
# Inserted 4824 records into collection embeddings_512.
# Inserted 4842 records into collection embeddings_512.
# Inserted 4860 records into collection embeddings_512.
# Inserted 4878 records into collection embeddings_512.
# Inserted 4896 records into collection embeddings_512.
# Inserted 4914 records into collection embeddings_512.
# Inserted 4932 records into collection embeddings_512.
# Inserted 4950 records into collection embeddings_512.
# Inserted 4968 records into collection embeddings_512.
# Inserted 4986 records into collection embeddings_512.
# Inserted 5004 records into collection embeddings_512.
# Inserted 5022 records into collection embeddings_512.
# Inserted 5040 records into collection embeddings_512.
# Inserted 5058 records into collection embeddings_512.
# Inserted 5076 records into collection embeddings_512.
# Inserted 5094 records into collection embeddings_512.
# Inserted 5112 records into collection embeddings_512.
# Inserted 5130 records into collection embeddings_512.
# Inserted 5148 records into collection embeddings_512.
# Inserted 5166 records into collection embeddings_512.
# Inserted 5184 records into collection embeddings_512.
# Inserted 5202 records into collection embeddings_512.
# Inserted 5220 records into collection embeddings_512.
# Inserted 5238 records into collection embeddings_512.
# Inserted 5256 records into collection embeddings_512.
# Inserted 5274 records into collection embeddings_512.
# Inserted 5292 records into collection embeddings_512.
# Inserted 5310 records into collection embeddings_512.
# Inserted 5328 records into collection embeddings_512.
# Inserted 5346 records into collection embeddings_512.
# Inserted 5364 records into collection embeddings_512.
# Inserted 5382 records into collection embeddings_512.
# Inserted 5400 records into collection embeddings_512.
# Inserted 5418 records into collection embeddings_512.
# Inserted 5436 records into collection embeddings_512.
# Inserted 5454 records into collection embeddings_512.
# Inserted 5472 records into collection embeddings_512.
# Inserted 5490 records into collection embeddings_512.
# Inserted 5508 records into collection embeddings_512.
# Inserted 5526 records into collection embeddings_512.
# Inserted 5544 records into collection embeddings_512.
# Inserted 5562 records into collection embeddings_512.
# Inserted 5580 records into collection embeddings_512.
# Inserted 5598 records into collection embeddings_512.
# Inserted 5616 records into collection embeddings_512.
# Inserted 5634 records into collection embeddings_512.
# Inserted 5652 records into collection embeddings_512.
# Inserted 5670 records into collection embeddings_512.
# Inserted 5688 records into collection embeddings_512.
# Inserted 5706 records into collection embeddings_512.
# Inserted 5724 records into collection embeddings_512.
# Inserted 5742 records into collection embeddings_512.
# Inserted 5760 records into collection embeddings_512.
# Inserted 5778 records into collection embeddings_512.
# Inserted 5796 records into collection embeddings_512.
# Inserted 5814 records into collection embeddings_512.
# Inserted 5832 records into collection embeddings_512.
# Inserted 5850 records into collection embeddings_512.
# Inserted 5868 records into collection embeddings_512.
# Inserted 5886 records into collection embeddings_512.
# Inserted 5904 records into collection embeddings_512.
# Inserted 5922 records into collection embeddings_512.
# Inserted 5940 records into collection embeddings_512.
# Inserted 5958 records into collection embeddings_512.
# Inserted 5976 records into collection embeddings_512.
# Inserted 5994 records into collection embeddings_512.
# Inserted 6012 records into collection embeddings_512.
# Inserted 6030 records into collection embeddings_512.
# Inserted 6048 records into collection embeddings_512.
# Inserted 6066 records into collection embeddings_512.
# Inserted 6084 records into collection embeddings_512.
# Inserted 6102 records into collection embeddings_512.
# Inserted 6120 records into collection embeddings_512.
# Inserted 6138 records into collection embeddings_512.
# Inserted 6156 records into collection embeddings_512.
# Inserted 6174 records into collection embeddings_512.
# Inserted 6192 records into collection embeddings_512.
# Inserted 6210 records into collection embeddings_512.
# Inserted 6228 records into collection embeddings_512.
# Inserted 6246 records into collection embeddings_512.
# Inserted 6264 records into collection embeddings_512.
# Inserted 6282 records into collection embeddings_512.
# Inserted 6300 records into collection embeddings_512.
# Inserted 6318 records into collection embeddings_512.
# Inserted 6336 records into collection embeddings_512.
# Inserted 6354 records into collection embeddings_512.
# Inserted 6372 records into collection embeddings_512.
# Inserted 6390 records into collection embeddings_512.
# Inserted 6408 records into collection embeddings_512.
# Inserted 6426 records into collection embeddings_512.
# Inserted 6444 records into collection embeddings_512.
# Inserted 6462 records into collection embeddings_512.
# Inserted 6480 records into collection embeddings_512.
# Inserted 6498 records into collection embeddings_512.
# Inserted 6516 records into collection embeddings_512.
# Inserted 6534 records into collection embeddings_512.
# Inserted 6552 records into collection embeddings_512.
# Inserted 6570 records into collection embeddings_512.
# Inserted 6588 records into collection embeddings_512.
# Inserted 6606 records into collection embeddings_512.
# Inserted 6624 records into collection embeddings_512.
# Inserted 6642 records into collection embeddings_512.
# Inserted 6660 records into collection embeddings_512.
# Inserted 6678 records into collection embeddings_512.
# Inserted 6696 records into collection embeddings_512.
# Inserted 6714 records into collection embeddings_512.
# Inserted 6732 records into collection embeddings_512.
# Inserted 6750 records into collection embeddings_512.
# Inserted 6768 records into collection embeddings_512.
# Inserted 6786 records into collection embeddings_512.
# Inserted 6804 records into collection embeddings_512.
# Inserted 6822 records into collection embeddings_512.
# Inserted 6840 records into collection embeddings_512.
# Inserted 6858 records into collection embeddings_512.
# Inserted 6876 records into collection embeddings_512.
# Inserted 6894 records into collection embeddings_512.
# Inserted 6912 records into collection embeddings_512.
# Inserted 6930 records into collection embeddings_512.
# Inserted 6948 records into collection embeddings_512.
# Inserted 6966 records into collection embeddings_512.
# Inserted 6984 records into collection embeddings_512.
# Inserted 7002 records into collection embeddings_512.
# Inserted 7020 records into collection embeddings_512.
# Inserted 7038 records into collection embeddings_512.
# Inserted 7056 records into collection embeddings_512.
# Inserted 7074 records into collection embeddings_512.
# Inserted 7092 records into collection embeddings_512.
# Inserted 7110 records into collection embeddings_512.
# Inserted 7128 records into collection embeddings_512.
# Inserted 7146 records into collection embeddings_512.
# Inserted 7164 records into collection embeddings_512.
# Inserted 7182 records into collection embeddings_512.
# Inserted 7200 records into collection embeddings_512.
# Inserted 7218 records into collection embeddings_512.
# Inserted 7236 records into collection embeddings_512.
# Inserted 7254 records into collection embeddings_512.
# Inserted 7272 records into collection embeddings_512.
# Inserted 7290 records into collection embeddings_512.
# Inserted 7308 records into collection embeddings_512.
# Inserted 7326 records into collection embeddings_512.
# Inserted 7344 records into collection embeddings_512.
# Inserted 7362 records into collection embeddings_512.
# Inserted 7380 records into collection embeddings_512.
# Inserted 7398 records into collection embeddings_512.
# Inserted 7416 records into collection embeddings_512.
# Inserted 7434 records into collection embeddings_512.
# Inserted 7452 records into collection embeddings_512.
# Inserted 7470 records into collection embeddings_512.
# Inserted 7488 records into collection embeddings_512.
# Inserted 7506 records into collection embeddings_512.
# Inserted 7524 records into collection embeddings_512.
# Inserted 7542 records into collection embeddings_512.
# Inserted 7560 records into collection embeddings_512.
# Inserted 7578 records into collection embeddings_512.
# Inserted 7596 records into collection embeddings_512.
# Inserted 7614 records into collection embeddings_512.
# Inserted 7632 records into collection embeddings_512.
# Inserted 7650 records into collection embeddings_512.
# Inserted 7668 records into collection embeddings_512.
# Inserted 7686 records into collection embeddings_512.
# Inserted 7704 records into collection embeddings_512.
# Inserted 7722 records into collection embeddings_512.
# Inserted 7740 records into collection embeddings_512.
# Inserted 7758 records into collection embeddings_512.
# Inserted 7776 records into collection embeddings_512.
# Inserted 7794 records into collection embeddings_512.
# Inserted 7812 records into collection embeddings_512.
# Inserted 7830 records into collection embeddings_512.
# Inserted 7848 records into collection embeddings_512.
# Inserted 7866 records into collection embeddings_512.
# Inserted 7884 records into collection embeddings_512.
# Inserted 7902 records into collection embeddings_512.
# Inserted 7920 records into collection embeddings_512.
# Inserted 7938 records into collection embeddings_512.
# Inserted 7956 records into collection embeddings_512.
# Inserted 7974 records into collection embeddings_512.
# Inserted 7992 records into collection embeddings_512.
# Inserted 8010 records into collection embeddings_512.
# Inserted 8028 records into collection embeddings_512.
# Inserted 8046 records into collection embeddings_512.
# Inserted 8064 records into collection embeddings_512.
# Inserted 8082 records into collection embeddings_512.
# Inserted 8100 records into collection embeddings_512.
# Inserted 8118 records into collection embeddings_512.
# Inserted 8136 records into collection embeddings_512.
# Inserted 8154 records into collection embeddings_512.
# Inserted 8172 records into collection embeddings_512.
# Inserted 8190 records into collection embeddings_512.
# Inserted 8208 records into collection embeddings_512.
# Inserted 8226 records into collection embeddings_512.
# Inserted 8244 records into collection embeddings_512.
# Inserted 8262 records into collection embeddings_512.
# Inserted 8280 records into collection embeddings_512.
# Inserted 8298 records into collection embeddings_512.
# Inserted 8316 records into collection embeddings_512.
# Inserted 8334 records into collection embeddings_512.
# Inserted 8352 records into collection embeddings_512.
# Inserted 8370 records into collection embeddings_512.
# Inserted 8388 records into collection embeddings_512.
# Inserted 8406 records into collection embeddings_512.
# Inserted 8424 records into collection embeddings_512.
# Inserted 8442 records into collection embeddings_512.
# Inserted 8460 records into collection embeddings_512.
# Inserted 8478 records into collection embeddings_512.
# Inserted 8496 records into collection embeddings_512.
# Inserted 8514 records into collection embeddings_512.
# Inserted 8532 records into collection embeddings_512.
# Inserted 8550 records into collection embeddings_512.
# Inserted 8568 records into collection embeddings_512.
# Inserted 8586 records into collection embeddings_512.
# Inserted 8604 records into collection embeddings_512.
# Inserted 8622 records into collection embeddings_512.
# Inserted 8640 records into collection embeddings_512.
# Inserted 8658 records into collection embeddings_512.
# Inserted 8676 records into collection embeddings_512.
# Inserted 8694 records into collection embeddings_512.
# Inserted 8712 records into collection embeddings_512.
# Inserted 8730 records into collection embeddings_512.
# Inserted 8748 records into collection embeddings_512.
# Inserted 8766 records into collection embeddings_512.
# Inserted 8784 records into collection embeddings_512.
# Inserted 8802 records into collection embeddings_512.
# Inserted 8820 records into collection embeddings_512.
# Inserted 8838 records into collection embeddings_512.
# Inserted 8856 records into collection embeddings_512.
# Inserted 8874 records into collection embeddings_512.
# Inserted 8892 records into collection embeddings_512.
# Inserted 8910 records into collection embeddings_512.
# Inserted 8928 records into collection embeddings_512.
# Inserted 8946 records into collection embeddings_512.
# Inserted 8964 records into collection embeddings_512.
# Inserted 8982 records into collection embeddings_512.
# Inserted 9000 records into collection embeddings_512.
# Inserted 9018 records into collection embeddings_512.
# Inserted 9036 records into collection embeddings_512.
# Inserted 9054 records into collection embeddings_512.
# Inserted 9072 records into collection embeddings_512.
# Inserted 9090 records into collection embeddings_512.
# Inserted 9108 records into collection embeddings_512.
# Inserted 9126 records into collection embeddings_512.
# Inserted 9144 records into collection embeddings_512.
# Inserted 9162 records into collection embeddings_512.
# Inserted 9180 records into collection embeddings_512.
# Inserted 9198 records into collection embeddings_512.
# Inserted 9216 records into collection embeddings_512.
# Inserted 9234 records into collection embeddings_512.
# Inserted 9252 records into collection embeddings_512.
# Inserted 9270 records into collection embeddings_512.
# Inserted 9288 records into collection embeddings_512.
# Inserted 9306 records into collection embeddings_512.
# Inserted 9324 records into collection embeddings_512.
# Inserted 9342 records into collection embeddings_512.
# Inserted 9360 records into collection embeddings_512.
# Inserted 9378 records into collection embeddings_512.
# Inserted 9396 records into collection embeddings_512.
# Inserted 9414 records into collection embeddings_512.
# Inserted 9432 records into collection embeddings_512.
# Inserted 9450 records into collection embeddings_512.
# Inserted 9468 records into collection embeddings_512.
# Inserted 9486 records into collection embeddings_512.
# Inserted 9504 records into collection embeddings_512.
# Inserted 9522 records into collection embeddings_512.
# Inserted 9540 records into collection embeddings_512.
# Inserted 9558 records into collection embeddings_512.
# Inserted 9576 records into collection embeddings_512.
# Inserted 9594 records into collection embeddings_512.
# Inserted 9612 records into collection embeddings_512.
# Inserted 9630 records into collection embeddings_512.
# Inserted 9648 records into collection embeddings_512.
# Inserted 9666 records into collection embeddings_512.
# Inserted 9684 records into collection embeddings_512.
# Inserted 9702 records into collection embeddings_512.
# Inserted 9720 records into collection embeddings_512.
# Inserted 9738 records into collection embeddings_512.
# Inserted 9756 records into collection embeddings_512.
# Inserted 9774 records into collection embeddings_512.
# Inserted 9792 records into collection embeddings_512.
# Inserted 9810 records into collection embeddings_512.
# Inserted 9828 records into collection embeddings_512.
# Inserted 9846 records into collection embeddings_512.
# Inserted 9864 records into collection embeddings_512.
# Inserted 9882 records into collection embeddings_512.
# Inserted 9900 records into collection embeddings_512.
# Inserted 9918 records into collection embeddings_512.
# Inserted 9936 records into collection embeddings_512.
# Inserted 9954 records into collection embeddings_512.
# Inserted 9972 records into collection embeddings_512.
# Inserted 9990 records into collection embeddings_512.
# Inserted 10008 records into collection embeddings_512.
# Inserted 10026 records into collection embeddings_512.
# Inserted 10044 records into collection embeddings_512.
# Inserted 10062 records into collection embeddings_512.
# Inserted 10080 records into collection embeddings_512.
# Inserted 10098 records into collection embeddings_512.
# Inserted 10116 records into collection embeddings_512.
# Inserted 10134 records into collection embeddings_512.
# Inserted 10152 records into collection embeddings_512.
# Inserted 10170 records into collection embeddings_512.
# Inserted 10188 records into collection embeddings_512.
# Inserted 10206 records into collection embeddings_512.
# Inserted 10224 records into collection embeddings_512.
# Inserted 10242 records into collection embeddings_512.
# Inserted 10260 records into collection embeddings_512.
# Inserted 10278 records into collection embeddings_512.
# Inserted 10296 records into collection embeddings_512.
# Inserted 10314 records into collection embeddings_512.
# Inserted 10332 records into collection embeddings_512.
# Inserted 10350 records into collection embeddings_512.
# Inserted 10368 records into collection embeddings_512.
# Inserted 10386 records into collection embeddings_512.
# Inserted 10404 records into collection embeddings_512.
# Inserted 10422 records into collection embeddings_512.
# Inserted 10440 records into collection embeddings_512.
# Inserted 10458 records into collection embeddings_512.
# Inserted 10476 records into collection embeddings_512.
# Inserted 10494 records into collection embeddings_512.
# Inserted 10512 records into collection embeddings_512.
# Inserted 10530 records into collection embeddings_512.
# Inserted 10548 records into collection embeddings_512.
# Inserted 10566 records into collection embeddings_512.
# Inserted 10584 records into collection embeddings_512.
# Inserted 10602 records into collection embeddings_512.
# Inserted 10620 records into collection embeddings_512.
# Inserted 10638 records into collection embeddings_512.
# Inserted 10656 records into collection embeddings_512.
# Inserted 10674 records into collection embeddings_512.
# Inserted 10692 records into collection embeddings_512.
# Inserted 10710 records into collection embeddings_512.
# Inserted 10728 records into collection embeddings_512.
# Inserted 10746 records into collection embeddings_512.
# Inserted 10764 records into collection embeddings_512.
# Inserted 10782 records into collection embeddings_512.
# Inserted 10800 records into collection embeddings_512.
# Inserted 10818 records into collection embeddings_512.
# Inserted 10836 records into collection embeddings_512.
# Inserted 10854 records into collection embeddings_512.
# Inserted 10872 records into collection embeddings_512.
# Inserted 10890 records into collection embeddings_512.
# Inserted 10908 records into collection embeddings_512.
# Inserted 10926 records into collection embeddings_512.
# Inserted 10944 records into collection embeddings_512.
# Inserted 10962 records into collection embeddings_512.
# Inserted 10980 records into collection embeddings_512.
# Inserted 10998 records into collection embeddings_512.
# Inserted 11016 records into collection embeddings_512.
# Inserted 11034 records into collection embeddings_512.
# Inserted 11052 records into collection embeddings_512.
# Inserted 11070 records into collection embeddings_512.
# Inserted 11088 records into collection embeddings_512.
# Inserted 11106 records into collection embeddings_512.
# Inserted 11124 records into collection embeddings_512.
# Inserted 11142 records into collection embeddings_512.
# Inserted 11160 records into collection embeddings_512.
# Inserted 11178 records into collection embeddings_512.
# Inserted 11196 records into collection embeddings_512.
# Inserted 11214 records into collection embeddings_512.
# Inserted 11232 records into collection embeddings_512.
# Inserted 11250 records into collection embeddings_512.
# Inserted 11268 records into collection embeddings_512.
# Inserted 11286 records into collection embeddings_512.
# Inserted 11304 records into collection embeddings_512.
# Inserted 11322 records into collection embeddings_512.
# Inserted 11340 records into collection embeddings_512.
# Inserted 11358 records into collection embeddings_512.
# Inserted 11376 records into collection embeddings_512.
# Inserted 11394 records into collection embeddings_512.
# Inserted 11412 records into collection embeddings_512.
# Inserted 11430 records into collection embeddings_512.
# Inserted 11448 records into collection embeddings_512.
# Inserted 11466 records into collection embeddings_512.
# Inserted 11484 records into collection embeddings_512.
# Inserted 11502 records into collection embeddings_512.
# Inserted 11520 records into collection embeddings_512.
# Inserted 11538 records into collection embeddings_512.
# Inserted 11556 records into collection embeddings_512.
# Inserted 11574 records into collection embeddings_512.
# Inserted 11592 records into collection embeddings_512.
# Inserted 11610 records into collection embeddings_512.
# Inserted 11628 records into collection embeddings_512.
# Inserted 11646 records into collection embeddings_512.

# %%
print(f"Failed batches: {fails}")
# Out:
# Failed batches: []

# %%
index = {
    "index_type": "IVF_FLAT",
    "metric_type": "L2",
    "params": {"nlist": 128},
}
collection.create_index(field_name="embedding", index_params=index)
# Out:
# Status(code=0, message=)

# %%
collection.load()

# %%
random_song = pick_random_mp3(DATASET).with_suffix(".pkl")
print(f"Random mp3: {random_song}")
print(get_top_5_genres(random_song, "utils/mtg_jamendo_genre.json"))

with open(random_song, "rb") as f:
    file_info = pickle.load(f)
    query_embed = file_info.get("embedding_512")
    
search_params = {"metric_type": "L2", "params": {"nprobe": 10}}
result = collection.search([query_embed], "embedding", search_params, limit=10, offset=1, output_fields=["path"])
print('\n')
for element in result[0]:
    print(element)
# Out:
# Random mp3: MegaSet/Dub Incorporation/2005 - Dans Le Décor/09 - Face à soi.pkl
# ['reggae', 'dub', 'hiphop', 'rock', 'electronic']
#
#
# id: 2794, distance: 8.968767166137695, entity: {'path': 'MegaSet/Dub Incorporation/2005 - Dans Le Décor/02 - One Shot.mp3'}
# id: 2802, distance: 9.882335662841797, entity: {'path': 'MegaSet/Dub Incorporation/2005 - Dans Le Décor/06 - Décor.mp3'}
# id: 2804, distance: 10.682575225830078, entity: {'path': 'MegaSet/Dub Incorporation/2005 - Dans Le Décor/01 - Survie.mp3'}
# id: 2805, distance: 12.890682220458984, entity: {'path': 'MegaSet/Dub Incorporation/2005 - Dans Le Décor/04 - Chaines.mp3'}
# id: 2797, distance: 13.144603729248047, entity: {'path': 'MegaSet/Dub Incorporation/2005 - Dans Le Décor/10 - Speed ( Feat. David Hinds).mp3'}
# id: 2795, distance: 13.314383506774902, entity: {'path': 'MegaSet/Dub Incorporation/2005 - Dans Le Décor/12 - Never Stop.mp3'}
# id: 2798, distance: 14.644083023071289, entity: {'path': 'MegaSet/Dub Incorporation/2005 - Dans Le Décor/11 - La Corde Raide.mp3'}
# id: 7807, distance: 14.956341743469238, entity: {'path': 'MegaSet/Alborosie/Alborosie - 2008 - Soul Pirate/Alborosie - 11. Bad Mind.mp3'}
# id: 2808, distance: 14.958187103271484, entity: {'path': 'MegaSet/Dub Incorporation/2003 - Diversite/04 - Rudeboy.mp3'}
# id: 2803, distance: 15.663719177246094, entity: {'path': 'MegaSet/Dub Incorporation/2005 - Dans Le Décor/03 - Monnaie (Feat.Lyricson).mp3'}
